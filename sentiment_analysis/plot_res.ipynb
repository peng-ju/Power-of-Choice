# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.cm as cm
from matplotlib import rcParams

# %%
def plot_path(file_path):
    data = pd.read_csv(file_path)
    data_select = data[data["itr"] == -1]

    plt.figure()
    plt.plot(data_select["Epoch"],data_select["testacc"])
    plt.xlim(0, 150)
    plt.xticks(ticks=[0, 50, 100, 150], labels=["0", "50", "100", "150"])
    plt.yticks(ticks=[45, 55, 65, 75], labels=["45", "55", "65", "75"])
    plt.grid(True)
    plt.xlabel("communication round")
    plt.ylabel("accuracy")

    plt.figure()
    plt.plot(data_select["Epoch"],data_select["trainloss"], label = "trainloss")
    plt.plot(data_select["Epoch"],data_select["testloss"], label = "testloss")
    plt.xlim(0, 150)
    plt.xlabel("communication round")
    plt.ylabel("trainloss")
    plt.grid(True)
    plt.legend()

def plot_folder(folder_path):
    c_t = cm.get_cmap('tab10')
    ftsize = 16
    params = {'legend.fontsize': ftsize,
             'axes.labelsize': ftsize,
             'axes.titlesize':ftsize,
             'xtick.labelsize':ftsize,
             'ytick.labelsize':ftsize}
    plt.rcParams.update(params)
    lw = 2
    plt.rcParams["font.family"] = "Times New Roman"
    plt.rcParams['axes.labelweight'] = 'bold'
    # plt.figure(figsize=(16,14.5))
    plt.subplots_adjust(right=1.1, top=0.9)
    rcParams['axes.titlepad'] = 14
    plt.rcParams['text.usetex'] = False
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        data = pd.read_csv(file_path)
        data_select = data[data["itr"] == -1]
        axs[0].plot(data_select["Epoch"],data_select["testacc"], label = file_name.split("_")[0])
        axs[0].legend()
        axs[0].set_xlabel("communication round")
        axs[0].set_ylabel("test accuracy (%)")
        axs[0].set_xticks(ticks=[0, 50, 100, 150], labels=["0", "50", "100", "150"])
        axs[0].set_yticks(ticks=[45, 55, 65, 75], labels=["45", "55", "65", "75"])
        axs[0].grid(True)

        axs[1].plot(data_select["Epoch"],data_select["trainloss"], label = file_name.split("_")[0])
        axs[1].legend()
        axs[1].set_xlabel("communication round")
        axs[1].set_ylabel("train loss")

# %%
plot_folder("/home/peng/workspace/Power-of-Choice/MLP_sentiment_analysis_Twitter/logs/default/lr0.0050_bs32_cp100_a0.20_e1_r0_n314_f0.10")

# %%
plot_folder("./logs/20231125/dataplot_lowlr")
# Out:
# /tmp/ipykernel_51382/4189003677.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c_t = cm.get_cmap('tab10')

# %%
folder_path = "./logs/20231125/dataplot_lowlr"

c_t = cm.get_cmap('tab10')
ftsize = 16
params = {'legend.fontsize': ftsize,
         'axes.labelsize': ftsize,
         'axes.titlesize':ftsize,
         'xtick.labelsize':ftsize,
         'ytick.labelsize':ftsize}
plt.rcParams.update(params)
lw = 2
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['axes.labelweight'] = 'bold'
# plt.figure(figsize=(16,14.5))
plt.subplots_adjust(right=1.1, top=0.9)
rcParams['axes.titlepad'] = 14
plt.rcParams['text.usetex'] = False
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

algo_list = ["pow-d", "rand", "rpow-d", "afl"]
color_list = ["k", c_t(3), c_t(0), c_t(2)]
file_list = os.listdir(folder_path)
file_list.sort(reverse = True)

for i,file_name in enumerate(file_list):
    file_path = os.path.join(folder_path, file_name)
    data = pd.read_csv(file_path)
    data_select = data[data["itr"] == -1]
    axs[0].plot(data_select["Epoch"],data_select["testacc"], color=color_list[i] ,label = file_name.split("_")[0])
    axs[0].legend()
    axs[0].set_xlabel("communication round")
    axs[0].set_ylabel("test accuracy (%)")
    axs[0].set_xticks(ticks=[0, 50, 100, 150, 200], labels=["0", "50", "100", "150", "200"])
    axs[0].set_yticks(ticks=[50, 55, 60, 65, 70], labels=["50", "", "60", "", "70"])
    axs[0].grid(True)
    axs[0].set_xlim([0, 200])
    axs[0].set_ylim([49, 72])

    axs[1].plot(data_select["Epoch"],data_select["trainloss"], color=color_list[i], label = file_name.split("_")[0])
    axs[1].legend()
    axs[1].set_xlabel("communication round")
    axs[1].set_ylabel("train loss")
# Out:
# /tmp/ipykernel_3328/2030225033.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c_t = cm.get_cmap('tab10')

# %%
plot_folder("./logs/20231125/dataplot_highlr")
# Out:
# /tmp/ipykernel_51382/4189003677.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c_t = cm.get_cmap('tab10')

# %%
folder_path = "./logs/20231125/dataplot_highlr"

c_t = cm.get_cmap('tab10')
ftsize = 16
params = {'legend.fontsize': ftsize,
         'axes.labelsize': ftsize,
         'axes.titlesize':ftsize,
         'xtick.labelsize':ftsize,
         'ytick.labelsize':ftsize}
plt.rcParams.update(params)
lw = 2
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['axes.labelweight'] = 'bold'
# plt.figure(figsize=(16,14.5))
plt.subplots_adjust(right=1.1, top=0.9)
rcParams['axes.titlepad'] = 14
plt.rcParams['text.usetex'] = False
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

algo_list = ["pow-d", "rand", "rpow-d", "afl"]
color_list = ["k", c_t(3), c_t(0), c_t(2)]
file_list = os.listdir(folder_path)
file_list.sort(reverse = True)

for i,file_name in enumerate(file_list):
    file_path = os.path.join(folder_path, file_name)
    data = pd.read_csv(file_path)
    data_select = data[data["itr"] == -1]
    axs[0].plot(data_select["Epoch"],data_select["testacc"], color=color_list[i] ,label = file_name.split("_")[0])
    axs[0].legend()
    axs[0].set_xlabel("communication round")
    axs[0].set_ylabel("test accuracy (%)")
    axs[0].set_xticks(ticks=[0, 50, 100, 150], labels=["0", "50", "100", "150"])
    axs[0].set_yticks(ticks=[45, 55, 65, 75], labels=["45", "55", "65", "75"])
    axs[0].grid(True)

    axs[1].plot(data_select["Epoch"],data_select["trainloss"], color=color_list[i], label = file_name.split("_")[0])
    axs[1].legend()
    axs[1].set_xlabel("communication round")
    axs[1].set_ylabel("train loss")
# Out:
# /tmp/ipykernel_51382/1765596319.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c_t = cm.get_cmap('tab10')

# %% [markdown]
# ## Plot the loss and accuracy curve for local training.

# %%
file_path = "/home/peng/workspace/Power-of-Choice/MLP_sentiment_analysis_Twitter/logs/default/lr0.0500_bs32_cp100_a0.20_e1_r0_n314_f0.10/rand_rr0.10_dr0.75_lr0.050_bs32_cp100_a0.20_e1_r0_n314_f0.10_p32.csv"
data = pd.read_csv(file_path)
data_select = data[data["itr"] != -1]

x_axis = np.array([i for i in range(len(data_select))])

N = 20


plt.figure(figsize=(10, 2))
plt.plot(x_axis[0:-N+1]/100, np.convolve(data_select["loss"], np.ones(N)/N, mode='valid'))
plt.ylabel("train loss")
plt.xlabel("client count")
plt.xlim(100,120)

plt.figure(figsize=(10, 2))
plt.plot(x_axis[0:-N+1]/100, np.convolve(data_select["Prec@1"], np.ones(N)/N, mode='valid'))
plt.xlim(100,120)
plt.xlabel("client count")
plt.ylabel("Accu")
# Out:
# Text(0, 0.5, 'Accu')
