# %%
from plot import make_plot

# %%
log_filenames = [
    './logs/fmnist_fig4a/lr0.0005_bs64_cp30_a2.00_e12345_r0_n0100_f0.03/rand_rr0.10_dr0.75_p0006_r0.csv',
    './logs/fmnist_fig4a/lr0.0005_bs64_cp30_a2.00_e12345_r0_n0100_f0.03/pow-d_rr0.10_dr0.75_p0006_r0.csv',
    './logs/fmnist_fig4a-norm/lr0.0005_bs64_cp30_a2.00_e12345_r0_n0100_f0.03/pow-norm_rr0.10_dr0.75_p0006_r0.csv',
]
# make_plot(log_filenames, 'test_loss', niters=200, save=True, save_path='./hello.pdf')
make_plot(log_filenames, 'test_acc', save=True, save_path='./hello.pdf')
# Out:
# saving plot to ./hello.pdf

# %%
log_filenames = [
    './logs/fmnist_fig4a/lr0.0005_bs64_cp30_a2.00_e12345_r0_n0100_f0.03/rand_rr0.10_dr0.75_p0006_r0.csv',
    './logs/fmnist_fig4a/lr0.0005_bs64_cp30_a2.00_e12345_r0_n0100_f0.03/pow-d_rr0.10_dr0.75_p0006_r0.csv',
    './logs/fmnist_fig4a-norm/lr0.0005_bs64_cp30_a2.00_e12345_r0_n0100_f0.03/pow-norm_rr0.10_dr0.75_p0006_r0.csv',
]
# make_plot(log_filenames, 'test_loss', niters=200, save=True, save_path='./hello.pdf')
make_plot(log_filenames, 'test_acc', save=False)

# %%
import numpy as np

# %%
a = np.array([3,2,1, np.inf])
b = sorted(a, reverse=True)

# %%
a, b
# Out:
# (array([ 3.,  2.,  1., inf]), [inf, 3.0, 2.0, 1.0])

# %%
# Out:
# inf
