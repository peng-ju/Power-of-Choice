# %%
from plot import make_plot

# %%
log_filenames = [
    './logs/synthetic_fig3-full-participation/lr0.0500_bs50_cp30_a0.20_e12345_r0_n0001_f1.00/rand_rr0.10_dr0.75_p0006_r0.csv',
    './logs/synthetic_fig3-full-participation/lr0.0500_bs50_cp30_a0.20_e12345_r0_n0030_f1.00/rand_rr0.10_dr0.75_p0006_r0.csv',
    './logs/synthetic_fig3b/lr0.0500_bs50_cp30_a0.20_e12345_r0_n0030_f0.10/rand_rr0.10_dr0.75_p0006_r0.csv',
    './logs/synthetic_fig3b/lr0.0500_bs50_cp30_a0.20_e12345_r0_n0030_f0.10/pow-d_rr0.10_dr0.75_p0006_r0.csv',
    # './logs/synthetic_fig3b/lr0.0500_bs50_cp30_a0.20_e12345_r0_n0030_f0.10/pow-d_rr0.10_dr0.75_p0030_r0.csv',
    # './logs/synthetic_fig3b/lr0.0500_bs50_cp30_a0.20_e12345_r0_n0030_f0.10/adapow-d_rr0.10_dr0.75_p0030_r0.csv'
]
make_plot(log_filenames, 'test_loss', niters=200, save=True, save_path='./hello.pdf')
# Out:
# saving plot to ./hello.pdf
