# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "./logs/default/lr0.0500_bs32_cp100_a0.20_e1_r0_n314_f0.03/test2.csv"

# %%
data = pd.read_csv(file_path)
data.head(5)

data_select = data[data["itr"] == -1]


data_select.head()
# Out:
#      Epoch  itr    loss  trainloss  avg:Loss  Prec@1  avg:Prec@1     val  \
# 100      0   -1  0.6991     0.7009        -1    -1.0          -1  50.699
# 201      1   -1  0.6996     0.7014        -1    -1.0          -1  50.699
# 302      2   -1  0.6962     0.6975        -1    -1.0          -1  50.699
# 403      3   -1  0.6938     0.6941        -1    -1.0          -1  50.699
# 504      4   -1  0.7002     0.6984        -1    -1.0          -1  50.699
#
#      trainval  updtime  comptime  seltime  entime  testacc  testloss
# 100    0.7009   3.6010       0.0   0.0023  3.6033   50.699    0.6991
# 201    0.7014   0.0942       0.0   0.0001  0.0943   50.699    0.6996
# 302    0.6975   0.0945       0.0   0.0001  0.0946   50.699    0.6962
# 403    0.6941   0.0931       0.0   0.0002  0.0932   50.699    0.6938
# 504    0.6984   0.1040       0.0   0.0002  0.1042   50.699    0.7002

# %%
# plt.plot(data["loss"])
# plt.plot(data.loc[0:100, "Epoch"])
# plt.plot(data["avg:Prec@1"])

# %%
# C = 0.03

# %%
plt.plot(data_select["Epoch"],data_select["testacc"])
plt.xlabel("communication round")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.plot(data_select["Epoch"],data_select["trainloss"], label = "trainloss")
plt.plot(data_select["Epoch"],data_select["testloss"], label = "testloss")
# plt.plot(data_select["Epoch"],data_select["loss"], label = "loss")
plt.xlabel("communication round")
plt.ylabel("trainloss")
plt.legend()

# %%
def plot_path(file_path):
    data = pd.read_csv(file_path)
    data_select = data[data["itr"] == -1]

    plt.figure()
    plt.plot(data_select["Epoch"],data_select["testacc"])
    plt.xlabel("communication round")
    plt.ylabel("accuracy")

    plt.figure()
    plt.plot(data_select["Epoch"],data_select["trainloss"], label = "trainloss")
    plt.plot(data_select["Epoch"],data_select["testloss"], label = "testloss")
    plt.xlabel("communication round")
    plt.ylabel("trainloss")
    plt.legend()

# %%
plot_path("./logs/default/lr0.0500_bs32_cp100_a0.20_e1_r0_n314_f0.10/rand_rr0.10_dr0.75_lr0.050_bs32_cp100_a0.20_e1_r0_n314_f0.10_p50.csv")
